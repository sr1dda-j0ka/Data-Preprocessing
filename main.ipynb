# %% [markdown]
# # importing modules

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # loading the dataset

# %%
df=pd.read_csv("dataset.csv")
df_copy = df.copy()
df=df.drop(["Date","Time"],axis=1)
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %% [markdown]
# # Handling missing values

# %%
pollutant_labels = ["CO(GT)", "NMHC(GT)", "C6H6(GT)", "NOx(GT)", "NO2(GT)"]
df.replace(-200,np.nan,inplace=True)
df.fillna(df.mean(),inplace=True)
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean      2.152750  1099.833166   218.811816    10.083105     939.153376
# std       1.316068   212.791672    63.870229     7.302650     261.560236
# min       0.100000   647.000000     7.000000     0.100000     383.000000
# 25%       1.200000   941.000000   218.811816     4.600000     743.000000
# 50%       2.152750  1075.000000   218.811816     8.600000     923.000000
# 75%       2.600000  1221.000000   218.811816    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    246.896735    835.493605   113.091251   1456.264598  1022.906128
# std     193.426632    251.743954    43.920954    339.367559   390.612324
# ...

# %% [markdown]
# # visualisation

# %%
df.hist(figsize=(12, 8), bins=30, edgecolor='black')
plt.suptitle("Feature Distributions", fontsize=14)
plt.show()

# %% [markdown]
# # scaling and encoding the data

# %%
num_cols=df.select_dtypes(include=[np.number]).columns
scaler=MinMaxScaler()
df[num_cols]=scaler.fit_transform(df[num_cols])
df.dtypes
# Out:
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %% [markdown]
# # Adding tables for date and time

# %%
df['Datetime'] = pd.to_datetime(df_copy['Date']+' '+df_copy['Time'])
df['Hour'] = df['Datetime'].dt.hour
df['Day'] = df['Datetime'].dt.day
df['Month'] = df['Datetime'].dt.month
df.drop(['Datetime'],axis=1,inplace=True)
df.dtypes
# Out:
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# Hour               int32
# Day                int32
# Month              int32
# dtype: object

# %% [markdown]
# # Detect Outliers using IQR

# %%
Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_no_outliers = df[~((df[num_cols] < lower_bound) | (df[num_cols] > upper_bound)).any(axis=1)]
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean      0.173962     0.325078     0.179198     0.156967       0.303743
# std       0.111531     0.152758     0.054036     0.114822       0.142851
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       0.093220     0.211055     0.179198     0.070755       0.196614
# 50%       0.173962     0.307251     0.179198     0.133648       0.294921
# 75%       0.211864     0.412060     0.179198     0.212264       0.394320
# max       1.000000     1.000000     1.000000     1.000000       1.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean      0.165807      0.217490     0.328672      0.407043     0.348352
# std       0.130959      0.106626     0.129944      0.152593     0.169684
# ...
